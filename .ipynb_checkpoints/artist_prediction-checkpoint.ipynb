# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./top_5000_albums_all_time.csv")
df.head()
# Out:
#    Ranking                             Album     Artist Name Release Date  \
# 0        1                       OK Computer       Radiohead    16-Jun-97
# 1        2                Wish You Were Here      Pink Floyd    12-Sep-75
# 2        3  In the Court of the Crimson King    King Crimson    10-Oct-69
# 3        4                             Kid A       Radiohead     3-Oct-00
# 4        5               To Pimp a Butterfly  Kendrick Lamar    15-Mar-15
#
#                                             Genres  \
# 0                       Alternative Rock, Art Rock
# 1                       Progressive Rock, Art Rock
# 2                       Progressive Rock, Art Rock
# 3          Art Rock, Experimental Rock, Electronic
# 4  Conscious Hip Hop, West Coast Hip Hop, Jazz Rap
#
#                                          Descriptors  Average Rating  \
# 0  melancholic, anxious, futuristic, alienation, ...            4.23
# 1  melancholic, atmospheric, progressive, male vo...            4.29
# 2  fantasy, epic, progressive, philosophical, com...            4.30
# 3  cold, melancholic, futuristic, atmospheric, an...            4.21
# 4  political, conscious, poetic, protest, concept...            4.27
#
#   Number of Ratings  Number of Reviews
# 0            70,382               1531
# 1            48,662                983
# 2            44,943                870
# 3            58,590                734
# 4            44,206                379

# %%
df = df.drop(columns = ['Release Date', 'Genres','Descriptors' ])
df.head()
# Out:
#    Ranking                             Album     Artist Name  Average Rating  \
# 0        1                       OK Computer       Radiohead            4.23
# 1        2                Wish You Were Here      Pink Floyd            4.29
# 2        3  In the Court of the Crimson King    King Crimson            4.30
# 3        4                             Kid A       Radiohead            4.21
# 4        5               To Pimp a Butterfly  Kendrick Lamar            4.27
#
#   Number of Ratings  Number of Reviews
# 0            70,382               1531
# 1            48,662                983
# 2            44,943                870
# 3            58,590                734
# 4            44,206                379

# %%
df2 = pd.read_csv("./artists.csv", sep='\t')
df2.head()
# Out:
#                 artist_id           name followers  popularity artist_type  \
# 0  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande  34554242          96      singer
# 1  26VFTg2z8YR0cCuwLzESi2         Halsey   7368242          90      singer
# 2  0Y5tJX1MQlPlqiwlOH1tJY   Travis Scott   6313709          94      rapper
# 3  246dkjvS1zLTtiykXe5h60    Post Malone  16737002          96      rapper
# 4  1zNqQNIdeOUZHb8zbZRFMX       Swae Lee    483032          89      singer
#
#    main_genre                                             genres  \
# 0   dance pop              ['dance pop', 'pop', 'post-teen pop']
# 1   dance pop  ['dance pop', 'electropop', 'etherpop', 'indie...
# 2         pop                          ['pop', 'pop rap', 'rap']
# 3     dfw rap                          ['dfw rap', 'pop', 'rap']
# 4  trap music                                     ['trap music']
#
#                                            image_url
# 0  https://i.scdn.co/image/b1dfbe843b0b9f54ab2e58...
# 1  https://i.scdn.co/image/22a5f3d8c42bc7cb55215e...
# 2  https://i.scdn.co/image/dc5eba5e032c2e5bc4d42c...
# 3  https://i.scdn.co/image/f9d8b742b66609f12da023...
# 4  https://i.scdn.co/image/a177469870b41f7e17e3b5...

# %%
df2 = df2.drop(columns = ['artist_id', 'artist_id', 'image_url'])
df2.head()
# Out:
#             name followers  popularity artist_type  main_genre  \
# 0  Ariana Grande  34554242          96      singer   dance pop
# 1         Halsey   7368242          90      singer   dance pop
# 2   Travis Scott   6313709          94      rapper         pop
# 3    Post Malone  16737002          96      rapper     dfw rap
# 4       Swae Lee    483032          89      singer  trap music
#
#                                               genres
# 0              ['dance pop', 'pop', 'post-teen pop']
# 1  ['dance pop', 'electropop', 'etherpop', 'indie...
# 2                          ['pop', 'pop rap', 'rap']
# 3                          ['dfw rap', 'pop', 'rap']
# 4                                     ['trap music']

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df2['followers'], df2['popularity'])
plt.xlabel('Followers')
plt.ylabel('Popularity')
plt.title('Artists Vs Popularity')
plt.show()
